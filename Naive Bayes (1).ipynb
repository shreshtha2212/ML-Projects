# %%
from sklearn.naive_bayes import GaussianNB
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
model_gaussian_naive_bayes=GaussianNB()

# %%
model_gaussian_naive_bayes.fit(X_train_resampled, y_train_resampled)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_888/1585380900.py in <module>
# ----> 1 model_gaussian_naive_bayes.fit()
#
# TypeError: fit() missing 2 required positional arguments: 'X' and 'y'

# %%
y_predict_naive_bayes=model.gaussian_naive_bayes.predict(X_test)

# %%
print(y_predict_naive_bayes)

# %%
print('confusion matrix')
print(confusion_matrix(y_test,y_predict_naive_bayes))

# %%
print('classification report')
print(Classification_report(y_test,y_predict_naive_bayes))

# %%
print('accuracy metrics')
print(accuracy_score(y_test,y_predict_naive_bayes))
