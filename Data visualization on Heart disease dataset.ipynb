# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
  
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# ## Age distplot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_12280\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'], kde=False)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_12280\2644285603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], kde=False)
# <Axes: xlabel='Age'>

# %%
sns.distplot(df['Age'], bins=5)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_12280\3305369760.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], bins=5)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'], bins=30)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_12280\1703443712.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], bins=30)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Distribution plot for numeric columns

# %%
sns.distplot(df['RestingBP'], kde=True, color='blue')
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_12280\1791409489.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'], kde=True, color='blue')
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df['Cholesterol'], kde=True, color='blue')
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_12280\936269024.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'], kde=True, color='blue')
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df['FastingBS'], kde=True, color='blue')
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_12280\2745976410.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['FastingBS'], kde=True, color='blue')
# <Axes: xlabel='FastingBS', ylabel='Density'>

# %%
sns.distplot(df['MaxHR'], kde=True, color='blue')
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_12280\1656756469.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MaxHR'], kde=True, color='blue')
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %%
sns.distplot(df['Oldpeak'], kde=True, color='blue')
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_12280\4149283870.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Oldpeak'], kde=True, color='blue')
# <Axes: xlabel='Oldpeak', ylabel='Density'>

# %% [markdown]
# ## Pie charts for categorical columns

# %%
df.groupby(df['Sex']).size()
# Out:
# Sex
# F    193
# M    725
# dtype: int64

# %%
df.groupby(df['Sex']).size().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: >

# %%
df.groupby(df['ChestPainType']).size()
# Out:
# ChestPainType
# ASY    496
# ATA    173
# NAP    203
# TA      46
# dtype: int64

# %%
df.groupby(df['Sex']).size().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: >

# %%
df.groupby(df['RestingECG']).size().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: >

# %%
df.groupby(df['ST_Slope']).size().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: >

# %%
df.groupby(df['HeartDisease']).size().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: >

# %%
df.groupby(df['ExerciseAngina']).size().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ## Heart disease EDA- Violin plot

# %%
sns.violinplot(df['Age']) # the middle dot in violin plot is the mean
# Out:
# <Axes: ylabel='Age'>

# %%
sns.violinplot(x=df['Sex'], y=df['HeartDisease'])
# Out:
# <Axes: xlabel='Sex', ylabel='HeartDisease'>

# %%
sns.violinplot(y=df['Age'], x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(y=df['RestingBP'], x=df['HeartDisease']) #it does not play that much important role
# Out:
# <Axes: xlabel='HeartDisease', ylabel='RestingBP'>

# %%
sns.violinplot(y=df['Cholesterol'], x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# ## Correlation(HeatMap)

# %%
df.corr(numeric_only=True)
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.jointplot(x='Age', y='MaxHR',data=df)

# %%
sns.jointplot(x='Age', y='Age',data=df)

# %%
sns.jointplot(x='Age', y='MaxHR',data=df, kind='hex')

# %%
sns.jointplot(x='Age', y='MaxHR',data=df, kind='reg')

# %%
sns.jointplot(x='Cholesterol', y='FastingBS',data=df, kind='reg')

# %%
sns.jointplot(x='HeartDisease', y='MaxHR',data=df, kind='reg')

# %% [markdown]
# ## Correlation (pairplot)

# %%
sns.pairplot(df)
